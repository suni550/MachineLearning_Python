# %% [markdown]
# # Activity 5: Create python file for detecting image from video
# # - Import required packages Numpy,OS,cv2
# # - Read the yml file created in Activity 2
# # - Captures frame and returns boolean value and captured image
# # - Predicting the label of given image
# # - If confidence less than 40 then don't print predicted face text on screen
# # - Create while loop to convert video to image until ‘q’ key is pressed

# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Jan 30 08:13:24 2022
@author: bobbala
"""
import cv2

import Activity_2
# Out:
# Model Trained Sucessfully

# %% [markdown]
# #### In below section, first read the trained yml file
#     #### Open webcam
#     #### Read the frames using cap.read()
# #### Call the predict method to predict the test image. This function returns 1. id of the person and 2. confidence level.
#
# - Create a list 'names' based on the training dataset. In the training data set I provided two persons datasets with ids 1 and 2. So create 'names' list with those two persons names + names[0] as 'None' because, the training ids of persons starts with 1. If the training dataset ids starts with '0' then no need to give names[0] = 'None'
# ![image-2.png](attachment:image-2.png)
#
# - If ids of training data sets starts with 0 as shown below then 'list 'names' = ['Vanisha', 'Sunil']; no need to use names[0] = 'None'.
# ![image.png](attachment:image.png)
#
# - IF the confidence level is <40 do not display the image.
# - Else, drawthe rectangle around the face, display the name of person and display the image.

# %%
#This module captures images via webcam and performs face recognition
face_recognizer = cv2.face.LBPHFaceRecognizer_create()

face_recognizer.read('trainingData.yml')
print("Reading of .yml is completed")
name = ['None', 'Vanisha', 'Sunil']

cap=cv2.VideoCapture(0)

while True:
    ret,frame =cap.read()# captures frame and returns boolean value and captured image
    
    faces_detected, gray_img = Activity_2.faceDetection(frame)

    for face in faces_detected:
        (x,y,w,h)=face
        roi_gray=gray_img[y:y+w, x:x+h] # Crop only the face region from gray image
        label,confidence=face_recognizer.predict(roi_gray)#predicting the label and confidence of given image
        confidence = int(100-confidence)
        print("confidence:",confidence)
        print("label:",label)
        
        gray_img = Activity_2.drawRectangle(faces_detected, frame)

        predicted_name=name[label]
        Activity_2.put_text(frame, predicted_name, x+5, y-5)

        if confidence < 40:
             continue

    cv2.imshow('face recognition tutorial ',frame)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Reading of .yml is completed
# face detected: [[372 273 152 152]]
# confidence: 26
# label: 2
# face detected: [[374 273 152 152]]
# confidence: 23
# label: 1
# face detected: [[371 272 155 155]]
# confidence: 27
# label: 1
# face detected: [[374 272 153 153]]
# confidence: 23
# label: 1
# face detected: [[375 273 152 152]]
# confidence: 23
# label: 1
# face detected: [[373 272 155 155]]
# confidence: 28
# label: 1
# face detected: [[374 272 152 152]]
# confidence: 25
# label: 2
# face detected: [[374 270 155 155]]
# confidence: 25
# label: 2
# face detected: [[375 272 153 153]]
# confidence: 24
# label: 2
# face detected: [[377 274 149 149]]
# confidence: 24
# label: 1
# face detected: [[374 274 149 149]]
# confidence: 24
# label: 1
# face detected: [[366 271 159 159]]
# confidence: 30
# label: 1
# face detected: [[369 275 155 155]]
# confidence: 27
# label: 2
# face detected: [[367 273 155 155]]
# confidence: 26
# label: 2
# face detected: [[367 275 153 153]]
# confidence: 30
# label: 2
# face detected: [[369 276 153 153]]
# confidence: 27
# label: 2
# face detected: [[366 276 153 153]]
# confidence: 30
# label: 2
# face detected: [[365 275 153 153]]
# confidence: 31
# label: 2
# face detected: [[362 275 155 155]]
# confidence: 30
# label: 2
# face detected: [[361 274 155 155]]
# confidence: 31
# label: 2
# face detected: [[360 275 154 154]]
# confidence: 30
# label: 2
# face detected: [[363 279 148 148]]
# confidence: 31
# label: 2
# face detected: [[359 275 155 155]]
# confidence: 31
# label: 2
# face detected: [[358 276 155 155]]
# confidence: 31
# label: 2
# face detected: [[357 273 157 157]]
# confidence: 32
# label: 2
# face detected: [[357 276 153 153]]
# confidence: 33
# label: 2
# face detected: [[358 275 153 153]]
# confidence: 34
# label: 2
# face detected: [[357 274 157 157]]
# confidence: 33
# label: 2
# face detected: [[360 276 151 151]]
# confidence: 32
# label: 2
# face detected: [[358 275 153 153]]
# confidence: 36
# label: 2
# face detected: [[354 274 158 158]]
# confidence: 33
# label: 2
# face detected: [[350 272 158 158]]
# confidence: 33
# label: 2
# face detected: [[349 272 160 160]]
# confidence: 34
# label: 2
# face detected: [[352 273 155 155]]
# confidence: 32
# label: 2
# face detected: [[348 274 155 155]]
# confidence: 34
# label: 2
# face detected: [[352 274 152 152]]
# confidence: 33
# label: 2
# face detected: [[351 276 153 153]]
# confidence: 33
# label: 2
# face detected: [[348 274 158 158]]
# confidence: 32
# label: 2
# face detected: [[347 274 160 160]]
# confidence: 33
# label: 2
# face detected: [[348 274 157 157]]
# confidence: 33
# label: 2
# face detected: [[349 275 155 155]]
# confidence: 31
# label: 2
# face detected: [[347 276 157 157]]
# confidence: 35
# label: 2
# face detected: [[352 275 150 150]]
# confidence: 33
# label: 2
# face detected: [[344 271 164 164]]
# confidence: 34
# label: 2
# face detected: [[347 273 159 159]]
# confidence: 34
# label: 2
# face detected: [[346 274 160 160]]
# confidence: 35
# label: 2
# face detected: [[346 273 158 158]]
# confidence: 33
# label: 2
# face detected: [[351 276 152 152]]
# confidence: 34
# label: 2
# face detected: [[346 273 161 161]]
# confidence: 34
# label: 2
# face detected: [[351 276 150 150]]
# confidence: 34
# label: 2
# face detected: [[350 276 152 152]]
# confidence: 34
# label: 2
# face detected: [[348 276 153 153]]
# confidence: 34
# label: 2
# face detected: [[349 274 153 153]]
# confidence: 34
# label: 2
# face detected: [[346 273 156 156]]
# confidence: 36
# label: 2
# face detected: [[346 272 159 159]]
# confidence: 33
# label: 2
# face detected: [[345 274 157 157]]
# confidence: 34
# label: 2
# face detected: [[346 274 157 157]]
# confidence: 34
# label: 2
# face detected: [[341 270 164 164]]
# confidence: 35
# label: 2
# face detected: [[345 272 159 159]]
# confidence: 35
# label: 2
# face detected: [[344 271 162 162]]
# confidence: 34
# label: 2
# face detected: [[346 273 157 157]]
# confidence: 32
# label: 2
# face detected: [[347 272 158 158]]
# confidence: 33
# label: 2
# face detected: [[348 273 157 157]]
# confidence: 32
# label: 2
# face detected: [[349 274 155 155]]
# confidence: 33
# label: 2
# face detected: [[346 273 160 160]]
# confidence: 34
# label: 2
# face detected: [[349 274 155 155]]
# confidence: 32
# label: 2
# face detected: [[344 271 164 164]]
# confidence: 32
# label: 2
# face detected: [[350 275 154 154]]
# confidence: 31
# label: 2
# face detected: [[345 272 160 160]]
# confidence: 34
# label: 2
# face detected: [[346 273 160 160]]
# confidence: 33
# label: 2
# face detected: [[348 274 155 155]]
# confidence: 34
# label: 2
# face detected: [[347 273 158 158]]
# confidence: 34
# label: 2
# face detected: [[343 270 166 166]]
# confidence: 33
# label: 2
# face detected: [[346 274 159 159]]
# confidence: 33
# label: 2
# face detected: [[347 273 158 158]]
# confidence: 33
# label: 2
# face detected: [[347 273 157 157]]
# confidence: 33
# label: 2
# face detected: [[347 274 158 158]]
# confidence: 32
# label: 2
# face detected: [[352 278 146 146]]
# confidence: 31
# label: 2
# face detected: [[352 277 148 148]]
# confidence: 32
# label: 2
# face detected: [[343 275 157 157]]
# confidence: 34
# label: 2
# face detected: [[343 274 157 157]]
# confidence: 33
# label: 2
# face detected: [[344 275 153 153]]
# confidence: 34
# label: 2
# face detected: [[343 275 155 155]]
# confidence: 34
# label: 2
# face detected: [[341 276 155 155]]
# confidence: 33
# label: 2
# face detected: [[341 275 157 157]]
# confidence: 34
# label: 2
# face detected: [[337 272 162 162]]
# confidence: 36
# label: 2
# face detected: [[339 274 159 159]]
# confidence: 33
# label: 2
# face detected: [[341 275 157 157]]
# confidence: 33
# label: 2
# face detected: [[343 276 154 154]]
# confidence: 33
# label: 2
# face detected: [[342 275 155 155]]
# confidence: 32
# label: 2
# face detected: [[340 275 157 157]]
# confidence: 34
# label: 2
# face detected: [[344 277 151 151]]
# confidence: 30
# label: 2
# face detected: [[340 275 157 157]]
# confidence: 34
# label: 2
# face detected: [[342 275 156 156]]
# confidence: 32
# label: 2
# face detected: [[341 276 155 155]]
# confidence: 33
# label: 2
# face detected: [[345 277 149 149]]
# confidence: 31
# label: 2
# face detected: [[343 276 151 151]]
# confidence: 31
# label: 2
# face detected: [[341 275 153 153]]
# confidence: 33
# label: 2
# face detected: [[346 275 152 152]]
# confidence: 31
# label: 2
# face detected: [[342 275 153 153]]
# confidence: 31
# label: 2
# face detected: [[344 276 152 152]]
# confidence: 31
# label: 2
# face detected: [[342 273 157 157]]
# confidence: 32
# label: 2
# face detected: [[341 273 157 157]]
# confidence: 32
# label: 2
# face detected: [[342 275 153 153]]
# confidence: 32
# label: 2
# face detected: [[346 277 150 150]]
# confidence: 30
# label: 2
# face detected: [[349 277 148 148]]
# confidence: 29
# label: 2
# face detected: [[343 272 158 158]]
# confidence: 30
# label: 2
# face detected: [[346 272 156 156]]
# confidence: 26
# label: 2
# face detected: [[339 267 167 167]]
# confidence: 29
# label: 2
# face detected: [[348 271 157 157]]
# confidence: 27
# label: 2
# face detected: [[348 271 157 157]]
# confidence: 27
# label: 2
# face detected: [[348 271 158 158]]
# confidence: 26
# label: 2
# face detected: [[347 270 160 160]]
# confidence: 29
# label: 2
# face detected: [[353 275 151 151]]
# confidence: 25
# label: 2
# face detected: [[351 275 153 153]]
# confidence: 30
# label: 2
# face detected: [[348 273 157 157]]
# confidence: 30
# label: 2
# face detected: [[348 273 159 159]]
# confidence: 30
# label: 2
# face detected: [[354 277 150 150]]
# confidence: 26
# label: 2
# face detected: [[351 275 153 153]]
# confidence: 29
# label: 2
# face detected: [[351 274 153 153]]
# confidence: 30
# label: 2
# face detected: [[350 275 153 153]]
# confidence: 30
# label: 2
# face detected: [[349 273 157 157]]
# confidence: 28
# label: 2
# face detected: [[351 275 155 155]]
# confidence: 27
# label: 2
# face detected: [[351 275 156 156]]
# confidence: 25
# label: 2
# face detected: [[351 274 155 155]]
# confidence: 27
# label: 2
# face detected: [[349 273 158 158]]
# confidence: 30
# label: 2
# face detected: [[349 274 158 158]]
# confidence: 29
# label: 2
# face detected: [[351 274 155 155]]
# confidence: 29
# label: 2
# face detected: [[353 276 152 152]]
# confidence: 27
# label: 2
# face detected: [[356 277 149 149]]
# confidence: 28
# label: 2
# face detected: [[350 273 160 160]]
# confidence: 29
# label: 2
# face detected: [[351 275 156 156]]
# confidence: 29
# label: 2
# face detected: [[353 275 153 153]]
# confidence: 29
# label: 2
# face detected: [[350 273 158 158]]
# confidence: 29
# label: 2
# face detected: [[352 272 156 156]]
# confidence: 29
# label: 2
# face detected: [[350 274 158 158]]
# confidence: 31
# label: 2
# face detected: [[346 271 164 164]]
# confidence: 30
# label: 2
# face detected: [[352 273 156 156]]
# confidence: 29
# label: 2
# face detected: [[354 274 153 153]]
# confidence: 28
# label: 2
# face detected: [[351 273 158 158]]
# confidence: 30
# label: 2
# face detected: [[347 271 165 165]]
# confidence: 29
# label: 2
# face detected: [[351 273 159 159]]
# confidence: 30
# label: 2
# face detected: [[352 272 160 160]]
# confidence: 28
# label: 2
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: [[392 276 151 151]]
# confidence: 17
# label: 2
# face detected: [[347 278 153 153]]
# confidence: 30
# label: 2
# face detected: [[345 277 155 155]]
# confidence: 35
# label: 2
# face detected: [[336 278 159 159]]
# confidence: 36
# label: 2
# face detected: [[334 278 158 158]]
# confidence: 36
# label: 2
# face detected: [[334 278 158 158]]
# confidence: 35
# label: 2
# face detected: [[332 277 161 161]]
# confidence: 34
# label: 2
# face detected: [[335 278 158 158]]
# confidence: 37
# label: 2
# face detected: [[336 279 155 155]]
# confidence: 38
# label: 2
# face detected: [[332 277 162 162]]
# confidence: 38
# label: 2
# face detected: [[336 277 159 159]]
# confidence: 38
# label: 2
# face detected: [[338 279 153 153]]
# confidence: 33
# label: 2
# face detected: [[336 277 157 157]]
# confidence: 37
# label: 2
# face detected: [[337 277 160 160]]
# confidence: 37
# label: 2
# face detected: [[340 279 153 153]]
# confidence: 33
# label: 2
# face detected: [[338 276 160 160]]
# confidence: 38
# label: 2
# face detected: [[340 276 156 156]]
# confidence: 39
# label: 2
# face detected: [[341 275 161 161]]
# confidence: 37
# label: 2
# face detected: [[345 278 151 151]]
# confidence: 36
# label: 2
# face detected: [[346 276 153 153]]
# confidence: 33
# label: 2
# face detected: [[346 276 161 161]]
# confidence: 28
# label: 2
# face detected: [[351 279 158 158]]
# confidence: 21
# label: 2
# face detected: [[356 284 155 155]]
# confidence: 18
# label: 2
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: ()
# face detected: [[365 294 151 151]]
# confidence: 13
# label: 1
