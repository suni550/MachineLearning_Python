# %% [markdown]
# ## Case Study 2
# ### Objective:
#     1. Practice Naive Bayes algorithm based classification.
#     2. Identify the predictors that can be of influence by experiment.
# ### Questions:
# 1. Load the kinematics dataset as measured on mobile sensors from the file “run_or_walk.csv”. List out the columns in the dataset.
# 2. Let the target variable ‘y’ be the activity and assign all the columns after it to ‘x’.
# 3. Using Scikit-learn fit a Gaussian Naive Bayes model and observe the accuracy. Generate a classification report using scikit learn.
# 4. Repeat the model once using only the acceleration values as predictors and then using only the gyro values as predictors. Comment on the difference in accuracy between both the models.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("run_or_walk.csv")
df
# Out:
#             date                time username  wrist  activity  \
# 0      2017-6-30  13:51:15:847724020   viktor      0         0
# 1      2017-6-30  13:51:16:246945023   viktor      0         0
# 2      2017-6-30  13:51:16:446233987   viktor      0         0
# 3      2017-6-30  13:51:16:646117985   viktor      0         0
# 4      2017-6-30  13:51:16:846738994   viktor      0         0
# ...          ...                 ...      ...    ...       ...
# 88583   2017-7-9   20:9:15:317911028   viktor      0         0
# 88584   2017-7-9   20:9:15:517889022   viktor      0         0
# 88585   2017-7-9   20:9:15:717828989   viktor      0         0
# 88586   2017-7-9   20:9:15:917932987   viktor      0         0
# 88587   2017-7-9   20:9:16:117410004   viktor      0         0
#
#        acceleration_x  acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0              0.2650         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# ...

# %%
df.activity.value_counts()
# From the below output we can say its almost a balanced dataset
# Out:
# 1    44365
# 0    44223
# Name: activity, dtype: int64

# %%
df.username.value_counts()
# Out:
# viktor    88588
# Name: username, dtype: int64

# %%
y = df.activity
X = df.iloc[:,5:]
X
# Out:
#        acceleration_x  acceleration_y  acceleration_z  gyro_x  gyro_y  gyro_z
# 0              0.2650         -0.7814         -0.0076 -0.0590  0.0325 -2.9296
# 1              0.6722         -1.1233         -0.2344 -0.1757  0.0208  0.1269
# 2              0.4399         -1.4817          0.0722 -0.9105  0.1063 -2.4367
# 3              0.3031         -0.8125          0.0888  0.1199 -0.4099 -2.9336
# 4              0.4814         -0.9312          0.0359  0.0527  0.4379  2.4922
# ...               ...             ...             ...     ...     ...     ...
# 88583          0.3084         -0.8376         -0.1327  0.4823  2.0124  0.6048
# 88584          0.4977         -1.0027         -0.4397  0.1022 -1.2565 -0.0761
# 88585          0.4587         -1.1780         -0.2827 -1.4500 -0.2792 -1.2616
# 88586          0.2590         -0.8582         -0.0759 -1.5165  0.4560 -1.7755
# 88587          0.3140         -0.8008         -0.0911  0.1183  1.0850  1.2814
#
# [88588 rows x 6 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 5)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

GNBclassifier = GaussianNB()
GNBclassifier.fit(X_train,y_train)
y_predict = GNBclassifier.predict(X_test)

# %%
print("Accuracy Score = ", accuracy_score(y_predict, y_test))
print("\n")
print("Classification Report:\n", classification_report(y_predict, y_test))

print("Confusion Matrix: \n", confusion_matrix(y_predict, y_test))
# Out:
# Accuracy Score =  0.956315611242804
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     14120
#            1       0.92      0.99      0.95     12457
#
#     accuracy                           0.96     26577
#    macro avg       0.96      0.96      0.96     26577
# weighted avg       0.96      0.96      0.96     26577
#
# Confusion Matrix:
#  [[13111  1009]
#  [  152 12305]]

# %% [markdown]
# ### Repeat the model once using only the acceleration values as predictors and then using only the gyro values as predictors. Comment on the difference in accuracy between both the models.

# %%
from sklearn.model_selection import train_test_split
#X, y = df.iloc[:, [5,6,7]].values,df.iloc[:, 4].values
X2 = df.iloc[:, 5:8]
y2 = df.iloc[:, 4]
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, test_size=0.2, random_state=1)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
GNBclassifier = GaussianNB()
GNBclassifier.fit(X_train2, y_train2)
y_predict2 = GNBclassifier.predict(X_test2)

# %%
print("Accuracy Score = ", accuracy_score(y_predict2, y_test2))
print("\n")
print("Classification Report:\n", classification_report(y_predict2, y_test2))

print("Confusion Matrix: \n", confusion_matrix(y_predict2, y_test2))
# Out:
# Accuracy Score =  0.9565978101365843
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.92      0.96      9316
#            1       0.92      0.99      0.96      8402
#
#     accuracy                           0.96     17718
#    macro avg       0.96      0.96      0.96     17718
# weighted avg       0.96      0.96      0.96     17718
#
# Confusion Matrix:
#  [[8610  706]
#  [  63 8339]]

# %%
from sklearn.model_selection import train_test_split
#X, y = df.iloc[:, [5,6,7]].values,df.iloc[:, 4].values
X3 = df.iloc[:, 8:11]
y3 = df.iloc[:, 4]
X_train3, X_test3, y_train3, y_test3 = train_test_split(X3, y3, test_size=0.2, random_state=1)

# %%
GNBclassifier = GaussianNB()
GNBclassifier.fit(X_train3, y_train3)
y_predict3 = GNBclassifier.predict(X_test3)

# %%
print("Accuracy Score = ", accuracy_score(y_predict3, y_test3))
print("\n")
print("Classification Report:\n", classification_report(y_predict3, y_test3))

print("Confusion Matrix: \n", confusion_matrix(y_predict3, y_test3))
# Out:
# Accuracy Score =  0.6475335816683598
#
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.61      0.68     10628
#            1       0.55      0.70      0.61      7090
#
#     accuracy                           0.65     17718
#    macro avg       0.65      0.66      0.64     17718
# weighted avg       0.67      0.65      0.65     17718
#
# Confusion Matrix:
#  [[6528 4100]
#  [2145 4945]]
